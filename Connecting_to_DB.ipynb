# %%
# Importing dependencies
import pandas as pd
from sqlalchemy import create_engine, inspect

# %%
# Creating the engine to link to AWS server
engine = create_engine("postgresql://postgres:B_Team_DataViz@b-team-final-project.cct7ahzel1ur.us-west-2.rds.amazonaws.com/B_Team_Final_Project")

# %%
# connecting to the server and creating a dataframe
places_county_df = pd.read_sql_table("places_county", con=engine)
places_county_df
# Out:
#      countyfips totalpopulation arthritis_crudeprev arthritis_adjprev  \
# 0         40065           24530                23.5              23.0
# 1         17101           15678                27.9              25.6
# 2         20009           25779                27.7              23.7
# 3          2020          288000                19.3              20.0
# 4         40137           43143                30.4              25.7
# ...         ...             ...                 ...               ...
# 3116      21043           26797                39.4              34.1
# 3117      28033          184945                25.7              24.6
# 3118      36085          476143                21.5              19.4
# 3119      20169           54224                25.9              22.9
# 3120      48497           69984                24.7              22.7
#
#      binge_crudeprev binge_adjprev bphigh_crudeprev bphigh_adjprev  \
# ...

# %%
# Examining data types
places_county_df.dtypes
# Out:
# countyfips             object
# totalpopulation        object
# arthritis_crudeprev    object
# arthritis_adjprev      object
# binge_crudeprev        object
#                         ...
# teethlost_crudeprev    object
# teethlost_adjprev      object
# geolocation            object
# county_state           object
# ruralurban             object
# Length: 63, dtype: object
